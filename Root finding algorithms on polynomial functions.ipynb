# %% [markdown]
# # Root finding algorithms on polynomial functions

# %% [markdown]
# ## Necessary imports

# %%
import numpy as np
import pandas as pd
import math
import sympy as smp
x = smp.symbols('x')

# %% [markdown]
# ## Method definitions

# %% [markdown]
# ### Newton's method

# %%
def newton_method(f, fprime, x_n, itercount = 1):
    
    xn_plus_1 = x_n - (f.subs(x, x_n).evalf() / fprime.subs(x, x_n).evalf())

    # if the derivative approaches zero and we're divirging
    if abs(fprime.subs(x, x_n).evalf()) < 10**-10:
        return (None, itercount)
    
    if abs(x_n - xn_plus_1) < 10**-6:
        return (xn_plus_1, itercount)
    else:
        return newton_method(f, fprime, xn_plus_1, itercount + 1)

# %% [markdown]
# ### Secant method

# %%
def secant_method(f, x_n, x_n_minus_1, itercount = 1):
    
    xn_plus_1 = x_n - f.subs(x, x_n).evalf() * (x_n - x_n_minus_1) / (f.subs(x, x_n).evalf() - f.subs(x, x_n_minus_1).evalf())

    # if the denominator approaches zero and we're divirging
    if abs(f.subs(x, x_n).evalf() - f.subs(x, x_n_minus_1).evalf()) < 10**-10:
        return (None, itercount)
    
    if abs(x_n - xn_plus_1) < 10**-6:
        return (xn_plus_1, itercount)
    else:
        return secant_method(f, xn_plus_1, x_n, itercount + 1)

# %% [markdown]
# ### Bisection method

# %%
def bisection_method(f, a, b, itercount = 1):
    
    c = (a + b) / 2
    if abs(c - a) < 10**-6:
        return (c, itercount)
    else:
        if f.subs(x, a).evalf() * f.subs(x, c).evalf() < 0:
            # root in between a and c
            return bisection_method(f, a, c, itercount + 1)
        # root in between c and b
        return bisection_method(f, c, b, itercount + 1)

# %% [markdown]
# ## Storing all functions in an array

# %%
functions = []

# (a)
f = 1 - 2*x* smp.exp(-x/2)
f_derivative = smp.diff(f, x)
x_0 = 0
b_for_secant_method = 6

functions.append({'f': f, 'f_derivative': f_derivative, 'initial_guess': x_0, 'b_for_secant_method': b_for_secant_method})

# (b)
f = 5 - x**-1
f_derivative = smp.diff(f, x)
x_0 = 1/4
b_for_secant_method = 0.16

functions.append({'f': f, 'f_derivative': f_derivative, 'initial_guess': x_0, 'b_for_secant_method': b_for_secant_method})

# (c)
f = x**3 - 2*x - 5
f_derivative = smp.diff(f, x)
x_0 = 2
b_for_secant_method = 3

functions.append({'f': f, 'f_derivative': f_derivative, 'initial_guess': x_0, 'b_for_secant_method': b_for_secant_method})

# (d)
f = smp.exp(x) - 2
f_derivative = smp.diff(f, x)
x_0 = 1
b_for_secant_method = 0


functions.append({'f': f, 'f_derivative': f_derivative, 'initial_guess': x_0, 'b_for_secant_method': b_for_secant_method})

# (e)
f = x - smp.exp(-x)
f_derivative = smp.diff(f, x)
x_0 = 1
b_for_secant_method = 0


functions.append({'f': f, 'f_derivative': f_derivative, 'initial_guess': x_0, 'b_for_secant_method': b_for_secant_method})

# (f)
f = x**6 - x - 1
f_derivative = smp.diff(f, x)
x_0 = 1
b_for_secant_method = 2


functions.append({'f': f, 'f_derivative': f_derivative, 'initial_guess': x_0, 'b_for_secant_method': b_for_secant_method})

# (g)
f = x**2 - smp.sin(x)
f_derivative = smp.diff(f, x)
x_0 = 1/2
b_for_secant_method = 2


functions.append({'f': f, 'f_derivative': f_derivative, 'initial_guess': x_0, 'b_for_secant_method': b_for_secant_method})

# (h)
f = x**3 - 2
f_derivative = smp.diff(f, x)
x_0 = 1
b_for_secant_method = 2


functions.append({'f': f, 'f_derivative': f_derivative, 'initial_guess': x_0, 'b_for_secant_method': b_for_secant_method})

# (i)
f = x + smp.tan(x)
f_derivative = smp.diff(f, x)
x_0 = 3
b_for_secant_method = 1


functions.append({'f': f, 'f_derivative': f_derivative, 'initial_guess': x_0, 'b_for_secant_method': b_for_secant_method})

# (j)
f = 2 - x**-1 * smp.ln(x)
f_derivative = smp.diff(f, x)
x_0 = 1/3

b_for_secant_method = 0.16

functions.append({'f': f, 'f_derivative': f_derivative, 'initial_guess': x_0, 'b_for_secant_method': b_for_secant_method})

# %% [markdown]
# ## Running the algorithms on all functions

# %%
result = []
for function in functions:
    f = function['f']
    f_prime = function['f_derivative']
    x_0 = function['initial_guess']
    b = function['b_for_secant_method']
    
    result_entry = {
        'function': f, 
        'Newton': newton_method(f, f_prime, x_0),
        'Secant': secant_method(f, x_0 + .0001, x_0),
        'Bisection': bisection_method(f, x_0, b)
    }
    result.append(result_entry)

# %% [markdown]
# ## Outputting the results

# %%
data = {
    "Function": [],
    "Method": [],
    "Approximation of Root": [],
    "Iterations": []
}

for entry in result:
    # f_latex = smp.latex(entry['function'])
    data["Function"].extend([entry['function']] * 3)
    # data["Function"].append('')

    data["Method"].append("Newton's method")
    data["Method"].append("Secant method")
    data["Method"].append("Bisection method")
    # data["Method"].append('')

    newton_root = 0
    secant_root = 0
    bisection_root = 0
    if(entry['Newton'][0] != None):
        newton_root = float(math.trunc(entry['Newton'][0] * 10**6) / 10**6)
    else:
        newton_root = None
        
    if(entry['Newton'][0] != None):
        secant_root = float(math.trunc(entry['Secant'][0] * 10**6) / 10**6)
    else:
        secant_root = None
    
    if(entry['Newton'][0] != None):
        bisection_root = float(math.trunc(entry['Bisection'][0] * 10**6) / 10**6)
    else:
        bisection_root = None
        

    data["Approximation of Root"].append(newton_root)
    data["Approximation of Root"].append(secant_root)
    data["Approximation of Root"].append(bisection_root)
    # data["Approximation of Root"].append('')

    data["Iterations"].append(entry['Newton'][1])
    data["Iterations"].append(entry['Secant'][1])
    data["Iterations"].append(entry['Bisection'][1])
    # data["Iterations"].append('')

df = pd.DataFrame(data)

df_styled = (df.style
             .set_properties(**{'text-align': 'center'})  # Center data
             .set_table_styles([{
                 'selector': 'th',  # Target column headers
                 'props': [('text-align', 'center')]  # Center headers
             }])
             .hide(axis="index")  # Hide the index
             # .format({'Function': lambda f: f"$\\displaystyle {f}$"})  # Display LaTeX-formatted functions
            )


display(df_styled)
# Out:
# <style type="text/css">
# #T_e3d9b th {
#   text-align: center;
# }
# #T_e3d9b_row0_col0, #T_e3d9b_row0_col1, #T_e3d9b_row0_col2, #T_e3d9b_row0_col3, #T_e3d9b_row1_col0, #T_e3d9b_row1_col1, #T_e3d9b_row1_col2, #T_e3d9b_row1_col3, #T_e3d9b_row2_col0, #T_e3d9b_row2_col1, #T_e3d9b_row2_col2, #T_e3d9b_row2_col3, #T_e3d9b_row3_col0, #T_e3d9b_row3_col1, #T_e3d9b_row3_col2, #T_e3d9b_row3_col3, #T_e3d9b_row4_col0, #T_e3d9b_row4_col1, #T_e3d9b_row4_col2, #T_e3d9b_row4_col3, #T_e3d9b_row5_col0, #T_e3d9b_row5_col1, #T_e3d9b_row5_col2, #T_e3d9b_row5_col3, #T_e3d9b_row6_col0, #T_e3d9b_row6_col1, #T_e3d9b_row6_col2, #T_e3d9b_row6_col3, #T_e3d9b_row7_col0, #T_e3d9b_row7_col1, #T_e3d9b_row7_col2, #T_e3d9b_row7_col3, #T_e3d9b_row8_col0, #T_e3d9b_row8_col1, #T_e3d9b_row8_col2, #T_e3d9b_row8_col3, #T_e3d9b_row9_col0, #T_e3d9b_row9_col1, #T_e3d9b_row9_col2, #T_e3d9b_row9_col3, #T_e3d9b_row10_col0, #T_e3d9b_row10_col1, #T_e3d9b_row10_col2, #T_e3d9b_row10_col3, #T_e3d9b_row11_col0, #T_e3d9b_row11_col1, #T_e3d9b_row11_col2, #T_e3d9b_row11_col3, #T_e3d9b_row12_col0, #T_e3d9b_row12_col1, #T_e3d9b_row12_col2, #T_e3d9b_row12_col3, #T_e3d9b_row13_col0, #T_e3d9b_row13_col1, #T_e3d9b_row13_col2, #T_e3d9b_row13_col3, #T_e3d9b_row14_col0, #T_e3d9b_row14_col1, #T_e3d9b_row14_col2, #T_e3d9b_row14_col3, #T_e3d9b_row15_col0, #T_e3d9b_row15_col1, #T_e3d9b_row15_col2, #T_e3d9b_row15_col3, #T_e3d9b_row16_col0, #T_e3d9b_row16_col1, #T_e3d9b_row16_col2, #T_e3d9b_row16_col3, #T_e3d9b_row17_col0, #T_e3d9b_row17_col1, #T_e3d9b_row17_col2, #T_e3d9b_row17_col3, #T_e3d9b_row18_col0, #T_e3d9b_row18_col1, #T_e3d9b_row18_col2, #T_e3d9b_row18_col3, #T_e3d9b_row19_col0, #T_e3d9b_row19_col1, #T_e3d9b_row19_col2, #T_e3d9b_row19_col3, #T_e3d9b_row20_col0, #T_e3d9b_row20_col1, #T_e3d9b_row20_col2, #T_e3d9b_row20_col3, #T_e3d9b_row21_col0, #T_e3d9b_row21_col1, #T_e3d9b_row21_col2, #T_e3d9b_row21_col3, #T_e3d9b_row22_col0, #T_e3d9b_row22_col1, #T_e3d9b_row22_col2, #T_e3d9b_row22_col3, #T_e3d9b_row23_col0, #T_e3d9b_row23_col1, #T_e3d9b_row23_col2, #T_e3d9b_row23_col3, #T_e3d9b_row24_col0, #T_e3d9b_row24_col1, #T_e3d9b_row24_col2, #T_e3d9b_row24_col3, #T_e3d9b_row25_col0, #T_e3d9b_row25_col1, #T_e3d9b_row25_col2, #T_e3d9b_row25_col3, #T_e3d9b_row26_col0, #T_e3d9b_row26_col1, #T_e3d9b_row26_col2, #T_e3d9b_row26_col3, #T_e3d9b_row27_col0, #T_e3d9b_row27_col1, #T_e3d9b_row27_col2, #T_e3d9b_row27_col3, #T_e3d9b_row28_col0, #T_e3d9b_row28_col1, #T_e3d9b_row28_col2, #T_e3d9b_row28_col3, #T_e3d9b_row29_col0, #T_e3d9b_row29_col1, #T_e3d9b_row29_col2, #T_e3d9b_row29_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_e3d9b">
#   <thead>
#     <tr>
#       <th id="T_e3d9b_level0_col0" class="col_heading level0 col0" >Function</th>
#       <th id="T_e3d9b_level0_col1" class="col_heading level0 col1" >Method</th>
#       <th id="T_e3d9b_level0_col2" class="col_heading level0 col2" >Approximation of Root</th>
#       <th id="T_e3d9b_level0_col3" class="col_heading level0 col3" >Iterations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e3d9b_row0_col0" class="data row0 col0" >-2*x*exp(-x/2) + 1</td>
#       <td id="T_e3d9b_row0_col1" class="data row0 col1" >Newton's method</td>
#       <td id="T_e3d9b_row0_col2" class="data row0 col2" >0.714805</td>
#       <td id="T_e3d9b_row0_col3" class="data row0 col3" >5</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row1_col0" class="data row1 col0" >-2*x*exp(-x/2) + 1</td>
#       <td id="T_e3d9b_row1_col1" class="data row1 col1" >Secant method</td>
#       <td id="T_e3d9b_row1_col2" class="data row1 col2" >0.714805</td>
#       <td id="T_e3d9b_row1_col3" class="data row1 col3" >7</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row2_col0" class="data row2 col0" >-2*x*exp(-x/2) + 1</td>
#       <td id="T_e3d9b_row2_col1" class="data row2 col1" >Bisection method</td>
#       <td id="T_e3d9b_row2_col2" class="data row2 col2" >0.714805</td>
#       <td id="T_e3d9b_row2_col3" class="data row2 col3" >23</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row3_col0" class="data row3 col0" >5 - 1/x</td>
#       <td id="T_e3d9b_row3_col1" class="data row3 col1" >Newton's method</td>
#       <td id="T_e3d9b_row3_col2" class="data row3 col2" >0.200000</td>
#       <td id="T_e3d9b_row3_col3" class="data row3 col3" >5</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row4_col0" class="data row4 col0" >5 - 1/x</td>
#       <td id="T_e3d9b_row4_col1" class="data row4 col1" >Secant method</td>
#       <td id="T_e3d9b_row4_col2" class="data row4 col2" >0.200000</td>
#       <td id="T_e3d9b_row4_col3" class="data row4 col3" >6</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row5_col0" class="data row5 col0" >5 - 1/x</td>
#       <td id="T_e3d9b_row5_col1" class="data row5 col1" >Bisection method</td>
#       <td id="T_e3d9b_row5_col2" class="data row5 col2" >0.200000</td>
#       <td id="T_e3d9b_row5_col3" class="data row5 col3" >17</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row6_col0" class="data row6 col0" >x**3 - 2*x - 5</td>
#       <td id="T_e3d9b_row6_col1" class="data row6 col1" >Newton's method</td>
#       <td id="T_e3d9b_row6_col2" class="data row6 col2" >2.094551</td>
#       <td id="T_e3d9b_row6_col3" class="data row6 col3" >4</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row7_col0" class="data row7 col0" >x**3 - 2*x - 5</td>
#       <td id="T_e3d9b_row7_col1" class="data row7 col1" >Secant method</td>
#       <td id="T_e3d9b_row7_col2" class="data row7 col2" >2.094551</td>
#       <td id="T_e3d9b_row7_col3" class="data row7 col3" >4</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row8_col0" class="data row8 col0" >x**3 - 2*x - 5</td>
#       <td id="T_e3d9b_row8_col1" class="data row8 col1" >Bisection method</td>
#       <td id="T_e3d9b_row8_col2" class="data row8 col2" >2.094552</td>
#       <td id="T_e3d9b_row8_col3" class="data row8 col3" >20</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row9_col0" class="data row9 col0" >exp(x) - 2</td>
#       <td id="T_e3d9b_row9_col1" class="data row9 col1" >Newton's method</td>
#       <td id="T_e3d9b_row9_col2" class="data row9 col2" >0.693147</td>
#       <td id="T_e3d9b_row9_col3" class="data row9 col3" >4</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row10_col0" class="data row10 col0" >exp(x) - 2</td>
#       <td id="T_e3d9b_row10_col1" class="data row10 col1" >Secant method</td>
#       <td id="T_e3d9b_row10_col2" class="data row10 col2" >0.693147</td>
#       <td id="T_e3d9b_row10_col3" class="data row10 col3" >5</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row11_col0" class="data row11 col0" >exp(x) - 2</td>
#       <td id="T_e3d9b_row11_col1" class="data row11 col1" >Bisection method</td>
#       <td id="T_e3d9b_row11_col2" class="data row11 col2" >0.693146</td>
#       <td id="T_e3d9b_row11_col3" class="data row11 col3" >20</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row12_col0" class="data row12 col0" >x - exp(-x)</td>
#       <td id="T_e3d9b_row12_col1" class="data row12 col1" >Newton's method</td>
#       <td id="T_e3d9b_row12_col2" class="data row12 col2" >0.567143</td>
#       <td id="T_e3d9b_row12_col3" class="data row12 col3" >4</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row13_col0" class="data row13 col0" >x - exp(-x)</td>
#       <td id="T_e3d9b_row13_col1" class="data row13 col1" >Secant method</td>
#       <td id="T_e3d9b_row13_col2" class="data row13 col2" >0.567143</td>
#       <td id="T_e3d9b_row13_col3" class="data row13 col3" >5</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row14_col0" class="data row14 col0" >x - exp(-x)</td>
#       <td id="T_e3d9b_row14_col1" class="data row14 col1" >Bisection method</td>
#       <td id="T_e3d9b_row14_col2" class="data row14 col2" >0.567143</td>
#       <td id="T_e3d9b_row14_col3" class="data row14 col3" >20</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row15_col0" class="data row15 col0" >x**6 - x - 1</td>
#       <td id="T_e3d9b_row15_col1" class="data row15 col1" >Newton's method</td>
#       <td id="T_e3d9b_row15_col2" class="data row15 col2" >1.134724</td>
#       <td id="T_e3d9b_row15_col3" class="data row15 col3" >5</td>
#     </tr>
#     <tr>
#       <td id="T_e3d9b_row16_col0" class="da
